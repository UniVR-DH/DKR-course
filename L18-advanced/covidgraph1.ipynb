# %% [markdown]
# <a href="https://colab.research.google.com/github/UniVR-DH/DKR-course/blob/main/L18-advanced/covidgraph1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graph Analysis of the Citation Graph of COVID Scientific Literature
#
# > Pestryakova, S., Vollmers, D., Sherif, M.A. et al.
# > CovidPubGraph: A FAIR Knowledge Graph of COVID-19 Publications. Sci Data 9, 389 (2022).
# > https://doi.org/10.1038/s41597-022-01298-2

# %% [markdown]
# ## BY: _______________________
#
# ## Scope and purpose:  Explorative Data Analysis
#
# This notebook will show an initial analysis of some aspects of the data contained in the above citation graph.
#
# The dataset is distributed in RDF format and in multiple snapshot at different points in time.
#
# **Some snapshots** of the dataset has been loaded into a SPARQL endpoint
#
# The snapshot will be analyzed by extracting data via SPARQL queries and analyzing portions of it with libraries and tools like `networkx`.

# %% [markdown]
# ## Imports and Utility Functions

# %%
# %%capture
# IF PACKAGES NEED TO BE INSTALLED


# !pip install networkx SPARQLWrapper

# %%
EDNPOINT='http://130.225.39.123:443/sparql'

# %%
import os
import glob
import string
import numpy as np
import pandas as pd
from pandas import json_normalize

import networkx as nx
import matplotlib.pyplot as plt
from SPARQLWrapper import SPARQLWrapper, JSON
from SPARQLWrapper.SPARQLExceptions import EndPointInternalError


pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

endpoint = SPARQLWrapper(EDNPOINT)
endpoint.setReturnFormat(JSON)
endpoint.setTimeout(1200)
endpoint.method = 'POST'


def run_query( query, endpoint, as_dataframe=False, do_print=False):
    # Utility function

    PREFIX= """
    PREFIX bibo: <http://purl.org/ontology/bibo/>
    PREFIX bibtex: <http://purl.org/net/nknouf/ns/bibtex#>
    PREFIX cvdo: <https://covid-19ds.data.dice-research.org/ontology/>
    PREFIX cvdr: <https://covid-19ds.data.dice-research.org/resource/>
    PREFIX dbo: <https://dbpedia.org/ontology/>
    PREFIX dcterms: <http://purl.org/dc/terms/>
    PREFIX fabio: <http://purl.org/spar/fabio/>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX its: <http://www.w3.org/2005/11/its/rdf#>
    PREFIX nif: <http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX prov: <http://www.w3.org/ns/prov#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX schema: <http://schema.org/>
    PREFIX sdo: <http://salt.semanticauthoring.org/ontologies/sdo#>
    PREFIX swc: <http://data.semanticweb.org/ns/swc/ontology#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

    """

    try:
        endpoint.setQuery(PREFIX+query)
        results = endpoint.query().convert()
        results = results['results']
        if len(results['bindings']) <= 0:
            print("Empty resultset")
            return None

        if not as_dataframe:
            if do_print:
                for binding in results['bindings']:
                    print("; ".join([var+": "+ binding[var]['value']  for var in binding.keys()  ]))
            return results['bindings']

        else:
            pdata = json_normalize(results['bindings'])
            if do_print:
                display(pdata)
            return pdata
    except EndPointInternalError  as e :
        print("Could not complete request!")
        return None

print("ready!")
# Out:
# ready!

# %% [markdown]
# ## Available snapshots
#
# ```
# https://covid-19ds.data.dice-research.org/2020-12-07
# https://covid-19ds.data.dice-research.org/2021-03-11
# https://covid-19ds.data.dice-research.org/2021-11-14
# ```

# %%
query = """

SELECT  (COUNT(*) as ?numTriples)
FROM <https://covid-19ds.data.dice-research.org/2020-12-07>
FROM <https://covid-19ds.data.dice-research.org/2021-11-14>
WHERE {
# ?s ?p ?o
}

"""

results = run_query(query, endpoint, as_dataframe=True, do_print=False)
display(results)
# Out:
#   numTriples.type                       numTriples.datatype numTriples.value
# 0   typed-literal  http://www.w3.org/2001/XMLSchema#integer        447284955

# %%
query = """

SELECT  (COUNT(*) as ?numTriples)
FROM <https://covid-19ds.data.dice-research.org/2021-11-14>
WHERE {
# ?s ?p ?o
}

"""

results = run_query(query, endpoint, as_dataframe=True, do_print=False)
display(results)
# Out:
#   numTriples.type                       numTriples.datatype numTriples.value
# 0   typed-literal  http://www.w3.org/2001/XMLSchema#integer        268080133

# %% [markdown]
# ## Exploratory Analysis
#
# ### Summarize node types and their prevalence in the graph

# %%
query = """
SELECT ?c COUNT(?s)
FROM <https://covid-19ds.data.dice-research.org/2021-11-14>
WHERE {
# ?s a ?c .
}

GROUP BY ?c
"""

results = run_query(query, endpoint, as_dataframe=True, do_print=True)
# Out:
#    c.type  \
# 0     uri
# 1     uri
# 2     uri
# 3     uri
# 4     uri
# 5     uri
# 6     uri
# 7     uri
# 8     uri
# 9     uri
# 10    uri
# 11    uri
# 12    uri
# 13    uri
# 14    uri
# 15    uri
# 16    uri
# 17    uri
# 18    uri
# 19    uri
# 20    uri
# 21    uri
# 22    uri
# 23    uri
# 24    uri
#
#                                                                          c.value  \
# 0             https://covid-19ds.data.dice-research.org/ontology/PaperBackground
# 1             https://covid-19ds.data.dice-research.org/ontology/PaperExperiment
# 2                                  http://purl.org/ontology/bibo/AcademicArticle
# 3                                               http://ma-graph.org/class/Author
# 4         http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Context
# 5                        http://salt.semanticauthoring.org/ontologies/sdo#Figure
# 6          http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#Phrase
# 7   http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#RFC5147String
# 8                         http://salt.semanticauthoring.org/ontologies/sdo#Table
# 9             https://covid-19ds.data.dice-research.org/ontology/PaperDiscussion
# 10                                              http://xmlns.com/foaf/0.1/Person
# 11                             http://data.semanticweb.org/ns/swc/ontology#Paper
# 12                           https://dbpedia.org/ontology/EducationalInstitution
# 13                                      http://purl.org/spar/fabio/ResearchPaper
# 14                                              http://www.w3.org/ns/prov#Entity
# 15                      http://salt.semanticauthoring.org/ontologies/sdo#Section
# 16                  https://covid-19ds.data.dice-research.org/ontology/PaperBody
# 17                                            http://schema.org/ScholarlyArticle
# 18         https://covid-19ds.data.dice-research.org/ontology/PaperPreliminaries
# 19           https://covid-19ds.data.dice-research.org/ontology/PaperRelatedWork
# 20         http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#String
# 21              https://covid-19ds.data.dice-research.org/ontology/PaperAbstract
# 22            https://covid-19ds.data.dice-research.org/ontology/PaperConclusion
# 23          https://covid-19ds.data.dice-research.org/ontology/PaperIntroduction
# 24                                    http://purl.org/net/nknouf/ns/bibtex#Entry
#
#    callret-1.type                        callret-1.datatype callret-1.value
# 0   typed-literal  http://www.w3.org/2001/XMLSchema#integer           18268
# 1   typed-literal  http://www.w3.org/2001/XMLSchema#integer           12188
# 2   typed-literal  http://www.w3.org/2001/XMLSchema#integer          262954
# 3   typed-literal  http://www.w3.org/2001/XMLSchema#integer         3388001
# 4   typed-literal  http://www.w3.org/2001/XMLSchema#integer         1332671
# 5   typed-literal  http://www.w3.org/2001/XMLSchema#integer         1532443
# 6   typed-literal  http://www.w3.org/2001/XMLSchema#integer        18266755
# 7   typed-literal  http://www.w3.org/2001/XMLSchema#integer         1332671
# 8   typed-literal  http://www.w3.org/2001/XMLSchema#integer          690478
# 9   typed-literal  http://www.w3.org/2001/XMLSchema#integer          127254
# 10  typed-literal  http://www.w3.org/2001/XMLSchema#integer         3388001
# 11  typed-literal  http://www.w3.org/2001/XMLSchema#integer          262954
# 12  typed-literal  http://www.w3.org/2001/XMLSchema#integer           77493
# 13  typed-literal  http://www.w3.org/2001/XMLSchema#integer          262954
# 14  typed-literal  http://www.w3.org/2001/XMLSchema#integer               1
# 15  typed-literal  http://www.w3.org/2001/XMLSchema#integer         9224555
# 16  typed-literal  http://www.w3.org/2001/XMLSchema#integer          262168
# 17  typed-literal  http://www.w3.org/2001/XMLSchema#integer          262954
# 18  typed-literal  http://www.w3.org/2001/XMLSchema#integer             910
# 19  typed-literal  http://www.w3.org/2001/XMLSchema#integer               1
# 20  typed-literal  http://www.w3.org/2001/XMLSchema#integer         1332671
# 21  typed-literal  http://www.w3.org/2001/XMLSchema#integer          189032
# 22  typed-literal  http://www.w3.org/2001/XMLSchema#integer          115832
# 23  typed-literal  http://www.w3.org/2001/XMLSchema#integer          152250
# 24  typed-literal  http://www.w3.org/2001/XMLSchema#integer         7748575

# %% [markdown]
# ### Summarize edge types and their prevalence in the graph

# %%
query = """

SELECT ?p COUNT(?p)
FROM <https://covid-19ds.data.dice-research.org/2021-11-14>
WHERE {
# ?s ?p ?o .
}

GROUP BY ?p
"""

results = run_query(query, endpoint, as_dataframe=True, do_print=True)
# Out:
#    p.type  \
# 0     uri
# 1     uri
# 2     uri
# 3     uri
# 4     uri
# 5     uri
# 6     uri
# 7     uri
# 8     uri
# 9     uri
# 10    uri
# 11    uri
# 12    uri
# 13    uri
# 14    uri
# 15    uri
# 16    uri
# 17    uri
# 18    uri
# 19    uri
# 20    uri
# 21    uri
# 22    uri
# 23    uri
# 24    uri
# 25    uri
# 26    uri
# 27    uri
# 28    uri
# 29    uri
# 30    uri
# 31    uri
# 32    uri
# 33    uri
# 34    uri
# 35    uri
# 36    uri
# 37    uri
# 38    uri
# 39    uri
# 40    uri
# 41    uri
# 42    uri
# 43    uri
# 44    uri
# 45    uri
# 46    uri
# 47    uri
# 48    uri
# 49    uri
# 50    uri
# 51    uri
#
#                                                                             p.value  \
# 0                                        http://www.w3.org/2000/01/rdf-schema#label
# 1                                       http://purl.org/net/nknouf/ns/bibtex#Inbook
# 2                                                      http://schema.org/EventVenue
# 3                                                             http://schema.org/url
# 4                  https://covid-19ds.data.dice-research.org/ontology/hasConclusion
# 5                                         http://www.w3.org/ns/prov#generatedAtTime
# 6                                      http://www.w3.org/2000/01/rdf-schema#seeAlso
# 7                                              http://www.w3.org/2002/07/owl#sameAs
# 8                        https://covid-19ds.data.dice-research.org/ontology/cordUid
# 9                                      http://purl.org/net/nknouf/ns/bibtex#hasYear
# 10                                                  http://purl.org/dc/terms/issued
# 11                          https://covid-19ds.data.dice-research.org/ontology/s2Id
# 12                                     http://purl.org/net/nknouf/ns/bibtex#hasISSN
# 13                                                http://purl.org/ontology/bibo/doi
# 14  http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#referenceContext
# 15                       https://covid-19ds.data.dice-research.org/ontology/arxivId
# 16                              http://purl.org/net/nknouf/ns/bibtex#hasInstitution
# 17                    https://covid-19ds.data.dice-research.org/ontology/hasSection
# 18          http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#isString
# 19                                     http://www.w3.org/2005/11/its/rdf#taIdentRef
# 20                                       http://www.w3.org/ns/prov#hadPrimarySource
# 21                                                   http://purl.org/dc/terms/title
# 22                                   http://purl.org/net/nknouf/ns/bibtex#hasVolume
# 23                                                 http://purl.org/dc/terms/license
# 24                                  http://purl.org/net/nknouf/ns/bibtex#hasJournal
# 25                     https://covid-19ds.data.dice-research.org/ontology/hasRegion
# 26                https://covid-19ds.data.dice-research.org/ontology/hasRelatedWork
# 27                                  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 28                                    http://purl.org/spar/fabio/hasPubMedCentralId
# 29          http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#anchorOf
# 30                       https://covid-19ds.data.dice-research.org/ontology/hasBody
# 31                                               http://xmlns.com/foaf/0.1/lastName
# 32                                         http://www.w3.org/ns/prov#wasDerivedFrom
# 33          http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#endIndex
# 34                                   http://purl.org/net/nknouf/ns/bibtex#hasAuthor
# 35                 https://covid-19ds.data.dice-research.org/ontology/hasDiscussion
# 36               https://covid-19ds.data.dice-research.org/ontology/hasIntroduction
# 37                       https://covid-19ds.data.dice-research.org/ontology/sourceX
# 38                                     http://www.w3.org/2006/vcard/ns#country-name
# 39                        https://covid-19ds.data.dice-research.org/ontology/hasLab
# 40                 https://covid-19ds.data.dice-research.org/ontology/hasSettlement
# 41                                    http://purl.org/net/nknouf/ns/bibtex#hasTitle
# 42                                               http://purl.org/ontology/bibo/pmid
# 43              https://covid-19ds.data.dice-research.org/ontology/hasPreliminaries
# 44                                              http://xmlns.com/foaf/0.1/firstName
# 45                                                   http://xmlns.com/foaf/0.1/mbox
# 46                 https://covid-19ds.data.dice-research.org/ontology/hasBackground
# 47                 https://covid-19ds.data.dice-research.org/ontology/hasExperiment
# 48                                                   http://xmlns.com/foaf/0.1/sha1
# 49        http://persistence.uni-leipzig.org/nlp2rdf/ontologies/nif-core#beginIndex
# 50                   https://covid-19ds.data.dice-research.org/ontology/hasAbstract
# 51                    https://covid-19ds.data.dice-research.org/ontology/middleName
#
#    callret-1.type                        callret-1.datatype callret-1.value
# 0   typed-literal  http://www.w3.org/2001/XMLSchema#integer           82038
# 1   typed-literal  http://www.w3.org/2001/XMLSchema#integer         5173888
# 2   typed-literal  http://www.w3.org/2001/XMLSchema#integer         6698403
# 3   typed-literal  http://www.w3.org/2001/XMLSchema#integer          262993
# 4   typed-literal  http://www.w3.org/2001/XMLSchema#integer          115832
# 5   typed-literal  http://www.w3.org/2001/XMLSchema#integer               1
# 6   typed-literal  http://www.w3.org/2001/XMLSchema#integer          262954
# 7   typed-literal  http://www.w3.org/2001/XMLSchema#integer         1902598
# 8   typed-literal  http://www.w3.org/2001/XMLSchema#integer          262992
# 9   typed-literal  http://www.w3.org/2001/XMLSchema#integer         7315102
# 10  typed-literal  http://www.w3.org/2001/XMLSchema#integer          262988
# 11  typed-literal  http://www.w3.org/2001/XMLSchema#integer          219925
# 12  typed-literal  http://www.w3.org/2001/XMLSchema#integer         1643938
# 13  typed-literal  http://www.w3.org/2001/XMLSchema#integer         3357145
# 14  typed-literal  http://www.w3.org/2001/XMLSchema#integer        19599426
# 15  typed-literal  http://www.w3.org/2001/XMLSchema#integer            9657
# 16  typed-literal  http://www.w3.org/2001/XMLSchema#integer          772671
# 17  typed-literal  http://www.w3.org/2001/XMLSchema#integer         9291953
# 18  typed-literal  http://www.w3.org/2001/XMLSchema#integer         9569375
# 19  typed-literal  http://www.w3.org/2001/XMLSchema#integer        19601436
# 20  typed-literal  http://www.w3.org/2001/XMLSchema#integer          262954
# 21  typed-literal  http://www.w3.org/2001/XMLSchema#integer          386562
# 22  typed-literal  http://www.w3.org/2001/XMLSchema#integer         6273184
# 23  typed-literal  http://www.w3.org/2001/XMLSchema#integer          262993
# 24  typed-literal  http://www.w3.org/2001/XMLSchema#integer          238743
# 25  typed-literal  http://www.w3.org/2001/XMLSchema#integer          236928
# 26  typed-literal  http://www.w3.org/2001/XMLSchema#integer               1
# 27  typed-literal  http://www.w3.org/2001/XMLSchema#integer        50244034
# 28  typed-literal  http://www.w3.org/2001/XMLSchema#integer          235697
# 29  typed-literal  http://www.w3.org/2001/XMLSchema#integer        19599431
# 30  typed-literal  http://www.w3.org/2001/XMLSchema#integer          262168
# 31  typed-literal  http://www.w3.org/2001/XMLSchema#integer         3440837
# 32  typed-literal  http://www.w3.org/2001/XMLSchema#integer               1
# 33  typed-literal  http://www.w3.org/2001/XMLSchema#integer        19647502
# 34  typed-literal  http://www.w3.org/2001/XMLSchema#integer        34172601
# 35  typed-literal  http://www.w3.org/2001/XMLSchema#integer          127254
# 36  typed-literal  http://www.w3.org/2001/XMLSchema#integer          152250
# 37  typed-literal  http://www.w3.org/2001/XMLSchema#integer          262993
# 38  typed-literal  http://www.w3.org/2001/XMLSchema#integer          612502
# 39  typed-literal  http://www.w3.org/2001/XMLSchema#integer          144566
# 40  typed-literal  http://www.w3.org/2001/XMLSchema#integer          657865
# 41  typed-literal  http://www.w3.org/2001/XMLSchema#integer        18985957
# 42  typed-literal  http://www.w3.org/2001/XMLSchema#integer          207004
# 43  typed-literal  http://www.w3.org/2001/XMLSchema#integer             910
# 44  typed-literal  http://www.w3.org/2001/XMLSchema#integer         3466889
# 45  typed-literal  http://www.w3.org/2001/XMLSchema#integer          116016
# 46  typed-literal  http://www.w3.org/2001/XMLSchema#integer           18268
# 47  typed-literal  http://www.w3.org/2001/XMLSchema#integer           12188
# 48  typed-literal  http://www.w3.org/2001/XMLSchema#integer          262984
# 49  typed-literal  http://www.w3.org/2001/XMLSchema#integer        19646864
# 50  typed-literal  http://www.w3.org/2001/XMLSchema#integer          189032
# 51  typed-literal  http://www.w3.org/2001/XMLSchema#integer         1547640

# %% [markdown]
# ### Additional analysis ...?

# %% [markdown]
# 1. **TODO: Run one additional query** that helps you understand the size and scope of the dataset
#
# 2. **REFLECT: Is there anything interesting/surprising/unexpected** from the results of the queries above?

# %% [markdown]
# ### Find the errors/mismatch in the ER schema presented in the original paper
#
# 1. **TODO: Select a subset of Fig1** in the original paper. **Identify any mismatch** between the schema presented there and the content of the dataset
# 2. **TODO: Produce an updated schema for the subset you studied**

# %%
###

# %% [markdown]
# ### Find the top 20 authors with the largerst number of papers in the collection

# %%
query = """

SELECT ?s COUNT(?o)
FROM <https://covid-19ds.data.dice-research.org/2021-11-14>
WHERE {
# ?s a <http://ma-graph.org/class/Author> .
# ?o <http://purl.org/net/nknouf/ns/bibtex#hasAuthor> ?s .
}
GROUP BY ?s
ORDER BY DESC(COUNT(?o))
LIMIT 20
"""

results = run_query(query, endpoint, as_dataframe=True, do_print=True)

# %% [markdown]
# ### Find the top 20 papers with the largerst number of referenced papers in the collection
#
# 1. **TODO: check** the initial query below
# 2. **TODO: update the query** so that it retrieves the required papers

# %%
## The following query retrieves all the references for a signle paper, you can use it as inspiration
query = """

SELECT DISTINCT ?paper1 ?paper2
FROM <https://covid-19ds.data.dice-research.org/2021-11-14>
WHERE {

VALUES ?paper1 { <https://covid-19ds.data.dice-research.org/resource/pmc1065257> }

# ?paper1 cvdo:hasBody ?body .
# ?body cvdo:hasSection ?section .
# ?refCont nif:referenceContext ?section .
# ?refCont its:taIdentRef ?entry .
# ?entry a bibtex:Entry .
# ?entry owl:sameAs ?paper2 .
# ?paper2 a  <http://schema.org/ScholarlyArticle> .

}
"""
results = run_query(query, endpoint, as_dataframe=True, do_print=True)

# %% [markdown]
# ### The Citation Network: loading Paper-cites->Paper subnetwork

# %% [markdown]
# **In the following:**
#
# - We extract the `paper-[cites]->paper` edges
# - We build a networkx Directed Graph
# - **TODO:** check out the tutorial of networkx here: [networkx.org/.../tutorial.html](https://networkx.org/documentation/stable/tutorial.html)
# - We extract the connected components and find the size of the largest one
# - **TODO:** The full citation graph is too big to be returned... we will need a smart solution
# - **REFLECT:** Decide how to edit the query or the code to obtain a reliable (even if imprecise/incomplete) result
# - **TODO:** Analyze the graph obtained, especially focusing on the largest connected component (see below)

# %%
query = """

SELECT DISTINCT ?paper1 ?paper2
FROM <https://covid-19ds.data.dice-research.org/2021-11-14>

WHERE {

# ?paper1 cvdo:hasBody ?body .
# ?body cvdo:hasSection ?section .
# ?refCont nif:referenceContext ?section .
# ?refCont its:taIdentRef ?entry .
# ?entry a bibtex:Entry .
# ?entry owl:sameAs ?paper2 .
# ?paper2 a  <http://schema.org/ScholarlyArticle> .

}
LIMIT 20000

"""

results = run_query(query, endpoint, as_dataframe=False, do_print=False)

len(results)
# Out:
# 20000

# %%
G = nx.DiGraph()
for binding in results:
    p1 = binding['paper1']['value']
    p2 = binding['paper2']['value']
    G.add_edge(p1, p2, label='cites')

print(nx.number_weakly_connected_components(G))

largest_cc = max(nx.weakly_connected_components(G), key=len)
len(largest_cc)
# Out:
# 665
# 10681

# %%
# NOTE: some metric requires to foucs on weakly connected components
largest_cc = max(nx.weakly_connected_components(G), key=len)

H = G.subgraph(largest_cc)
print(nx.density(H))
print(nx.diameter(H.to_undirected()))
np.median(nx.degree_histogram(H))

# %% [markdown]
# ## The Analysis Task
#
# Assume you are given information that some papers have been retracted because their findings were not valid.
#
# How much of the information of the graph are you able to exploit to identify other papers that might be "problematic"?
